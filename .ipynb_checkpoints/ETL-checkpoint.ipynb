# %% [markdown]
# ### Apple app store dataset extraction, transformation

# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
#import csv file into pandas
csv_data = pd.read_csv("AppleStore.csv", encoding="utf-8")
apple_df = pd.DataFrame(csv_data)
apple_df.head(10)

final_apple_df = apple_df[["track_name", "size_bytes", "user_rating", "rating_count_tot", "price", "cont_rating"]].copy()

# %%
#renamed with appended "_g" for google store columns and "_a" for apple store
final_apple_df.rename(columns = {'track_name':'App_Name', 'size_bytes': 'Size_a', 'user_rating': 'user_rating_a', 'rating_count_tot': 'rating_count_tot_a', 'price' : 'price_a', 'cont_rating': 'cont_rating_a'}, inplace = True)
final_apple_df.head()

final_apple_df.drop_duplicates(inplace = True)
final_apple_df.dropna(inplace = True)
final_apple_df.head()
# Out:
#                                             App_Name     Size_a  \
# 0                                    PAC-MAN Premium  100788224
# 1                          Evernote - stay organized  158578688
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts  100524032
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...  128512000
# 4                                              Bible   92774400
#
#    user_rating_a  rating_count_tot_a  price_a cont_rating_a
# 0            4.0               21292     3.99            4+
# 1            4.0              161065     0.00            4+
# 2            3.5              188583     0.00            4+
# 3            4.0              262241     0.00           12+
# 4            4.5              985920     0.00            4+

# %% [markdown]
# ### Google app store dataset extraction, transformation

# %% [markdown]
# ### Store Google Dataset CSV into DataFrame

# %%
csv_file = "Google-Playstore-Full.csv"
google_df = pd.read_csv(csv_file,low_memory=False)
google_df.head()
# Out:
#                                             App Name          Category  \
# 0                           DoorDash - Food Delivery    FOOD_AND_DRINK
# 1  TripAdvisor Hotels Flights Restaurants Attract...  TRAVEL_AND_LOCAL
# 2                                             Peapod          SHOPPING
# 3                    foodpanda - Local Food Delivery    FOOD_AND_DRINK
# 4                          My CookBook Pro (Ad Free)    FOOD_AND_DRINK
#
#         Rating  Reviews      Installs                Size  Price  \
# 0  4.548561573   305034    5,000,000+  Varies with device      0
# 1  4.400671482  1207922  100,000,000+  Varies with device      0
# 2  3.656329393     1967      100,000+                1.4M      0
# 3  4.107232571   389154   10,000,000+                 16M      0
# 4  4.647752285     2291       10,000+  Varies with device  $5.99
#
#   Content Rating        Last Updated     Minimum Version      Latest Version  \
# 0       Everyone      March 29, 2019  Varies with device  Varies with device
# 1       Everyone      March 29, 2019  Varies with device  Varies with device
# 2       Everyone  September 20, 2018          5.0 and up               2.2.0
# 3       Everyone      March 22, 2019          4.2 and up              4.18.2
# 4       Everyone       April 1, 2019  Varies with device  Varies with device
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13  Unnamed: 14
# 0         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN          NaN
# 2         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN          NaN
# 4         NaN         NaN         NaN          NaN

# %% [markdown]
# ### Create new data with select columns

# %%
new_google_df = google_df[['App Name', 'Category', 'Rating','Reviews','Installs','Size','Price','Content Rating']].copy()
new_google_df.head()
# Out:
#                                             App Name          Category  \
# 0                           DoorDash - Food Delivery    FOOD_AND_DRINK
# 1  TripAdvisor Hotels Flights Restaurants Attract...  TRAVEL_AND_LOCAL
# 2                                             Peapod          SHOPPING
# 3                    foodpanda - Local Food Delivery    FOOD_AND_DRINK
# 4                          My CookBook Pro (Ad Free)    FOOD_AND_DRINK
#
#         Rating  Reviews      Installs                Size  Price  \
# 0  4.548561573   305034    5,000,000+  Varies with device      0
# 1  4.400671482  1207922  100,000,000+  Varies with device      0
# 2  3.656329393     1967      100,000+                1.4M      0
# 3  4.107232571   389154   10,000,000+                 16M      0
# 4  4.647752285     2291       10,000+  Varies with device  $5.99
#
#   Content Rating
# 0       Everyone
# 1       Everyone
# 2       Everyone
# 3       Everyone
# 4       Everyone

# %% [markdown]
# ### Rename the columns based on the dataset source

# %%
google_renamed=new_google_df.rename(columns={"App Name":"App_Name","Category": "Category_g", "Rating": "Rating_g",
                              "Reviews":"Reviews_g","Installs":"Installs_g",
                              "Size":"Size_g","Price":"Price_g","Content Rating":"Content_Rating_g"})
google_renamed.head()

google_renamed.describe()
# Out:
#        App_Name Category_g Rating_g Reviews_g Installs_g              Size_g  \
# count    267051     267051   267052    267051     267052              267052
# unique   244406         67    99856     24544         38                1248
# top        ????  EDUCATION        5         1    10,000+  Varies with device
# freq        766      33394    23804      9203      60531               11726
#
#        Price_g Content_Rating_g
# count   267052           267052
# unique     504               12
# top          0         Everyone
# freq    255428           241578

# %% [markdown]
# ### Data Cleaning

# %%
google_renamed.dropna()

google_renamed.drop_duplicates(inplace=True)

google_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 267035 entries, 0 to 267051
# Data columns (total 8 columns):
# App_Name            267034 non-null object
# Category_g          267034 non-null object
# Rating_g            267035 non-null object
# Reviews_g           267034 non-null object
# Installs_g          267035 non-null object
# Size_g              267035 non-null object
# Price_g             267035 non-null object
# Content_Rating_g    267035 non-null object
# dtypes: object(8)
# memory usage: 18.3+ MB

# %%
app_df=google_renamed.merge(final_apple_df, how="inner", on="App_Name")

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1435 entries, 0 to 1434
# Data columns (total 13 columns):
# App_Name              1435 non-null object
# Category_g            1435 non-null object
# Rating_g              1435 non-null object
# Reviews_g             1435 non-null object
# Installs_g            1435 non-null object
# Size_g                1435 non-null object
# Price_g               1435 non-null object
# Content_Rating_g      1435 non-null object
# Size_a                1435 non-null int64
# user_rating_a         1435 non-null float64
# rating_count_tot_a    1435 non-null int64
# price_a               1435 non-null float64
# cont_rating_a         1435 non-null object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 157.0+ KB

# %%
app_df.head()
# Out:
#                     App_Name      Category_g     Rating_g Reviews_g  \
# 0   DoorDash - Food Delivery  FOOD_AND_DRINK  4.548561573    305034
# 1  Allrecipes Dinner Spinner  FOOD_AND_DRINK  4.545353413     67514
# 2         Domino's Pizza USA  FOOD_AND_DRINK  4.739675045   1177040
# 3                Chick-fil-A  FOOD_AND_DRINK  4.374690533     52526
# 4           Amazon Prime Now        SHOPPING  3.924423456     24849
#
#     Installs_g              Size_g Price_g Content_Rating_g     Size_a  \
# 0   5,000,000+  Varies with device       0         Everyone  100554752
# 1   5,000,000+  Varies with device       0         Everyone   36399104
# 2  10,000,000+  Varies with device       0         Everyone  105743360
# 3   5,000,000+                 19M       0         Everyone   96230400
# 4  10,000,000+                 38M       0             Teen   48007168
#
#    user_rating_a  rating_count_tot_a  price_a cont_rating_a
# 0            4.5               25947      0.0            4+
# 1            3.5              109349      0.0           12+
# 2            5.0              258624      0.0            4+
# 3            3.5                5665      0.0            4+
# 4            3.0                 895      0.0            4+

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "<insert user name>:<insert password>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#
# ~\.conda\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "<insert user name>"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-d72bc75a6b62> in <module>
# ----> 1 engine.table_names()
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in table_names(self, schema, connection)
#    2251         """
#    2252
# -> 2253         with self._optional_conn_ctx_manager(connection) as conn:
#    2254             if not schema:
#    2255                 schema = self.dialect.default_schema_name
#
# ~\.conda\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _optional_conn_ctx_manager(self, connection)
#    2035     def _optional_conn_ctx_manager(self, connection=None):
#    2036         if connection is None:
# -> 2037             with self._contextual_connect() as conn:
#    2038                 yield conn
#    2039         else:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2237         return self._connection_cls(
#    2238             self,
# -> 2239             self._wrap_pool_connect(self.pool.connect, None),
#    2240             close_with_result=close_with_result,
#    2241             **kwargs
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2277             if connection is None:
#    2278                 Connection._handle_dbapi_exception_noconnection(
# -> 2279                     e, dialect, self
#    2280                 )
#    2281             else:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1542             util.raise_from_cause(newraise, exc_info)
#    1543         elif should_wrap:
# -> 1544             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1545         else:
#    1546             util.reraise(*exc_info)
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2273         dialect = self.dialect
#    2274         try:
# -> 2275             return fn()
#    2276         except dialect.dbapi.Error as e:
#    2277             if connection is None:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     361         """
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#     365         try:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     758     def _checkout(cls, pool, threadconns=None, fairy=None):
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#     762             fairy._pool = pool
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     490     @classmethod
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#     494             dbapi_connection = rec.get_connection()
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     137             except:
#     138                 with util.safe_reraise():
# --> 139                     self._dec_overflow()
#     140         else:
#     141             return self._do_get()
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     134         if self._inc_overflow():
#     135             try:
# --> 136                 return self._create_connection()
#     137             except:
#     138                 with util.safe_reraise():
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     306         """Called by subclasses to create a new ConnectionRecord."""
#     307
# --> 308         return _ConnectionRecord(self)
#     309
#     310     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     435         self.__pool = pool
#     436         if connect:
# --> 437             self.__connect(first_connect_check=True)
#     438         self.finalize_callback = deque()
#     439
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     637         try:
#     638             self.starttime = time.time()
# --> 639             connection = pool._invoke_creator(self)
#     640             pool.logger.debug("Created new connection %r", connection)
#     641             self.connection = connection
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~\.conda\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     479
#     480     def connect(self, *cargs, **cparams):
# --> 481         return self.dbapi.connect(*cargs, **cparams)
#     482
#     483     def create_connect_args(self, url):
#
# ~\.conda\envs\PythonData\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "<insert user name>"
#
# (Background on this error at: http://sqlalche.me/e/e3q8)
